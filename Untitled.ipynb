# %%
 from buffguide.parse import text_to_dataframe

# %%
frame=text_to_dataframe("classData.txt")
# Out:
# didnt work
# didnt work
# didnt work
# didnt work
# didnt work
# didnt work
# didnt work
# didnt work
# didnt work
# didnt work
# didnt work
# didnt work
# didnt work
# didnt work
# didnt work
# didnt work
# didnt work
# didnt work
# didnt work
# didnt work
# didnt work
# didnt work
# didnt work
# didnt work
# didnt work
# didnt work
# didnt work
# didnt work
# didnt work
# didnt work
# didnt work
# didnt work
# didnt work
# didnt work
# didnt work
# didnt work
# didnt work
# didnt work
# didnt work
# didnt work
# didnt work
# didnt work
# didnt work
# didnt work
# didnt work
# didnt work
# didnt work
# didnt work
# didnt work
# didnt work
# didnt work
# didnt work
# didnt work
# didnt work
# didnt work
# didnt work
# didnt work
# didnt work
# didnt work
# didnt work
# didnt work
# didnt work
# didnt work
# didnt work
# didnt work
# didnt work
# didnt work
# didnt work
# didnt work
# didnt work
# didnt work
# didnt work
# didnt work
# didnt work
# didnt work
# didnt work
# ...

# %%
appm_classes = frame.loc[frame['classDept']=='APPM']

# %%
print(appm_classes)
# Out:
#    classDept classCourseNum classSectionNum classSessionNum  classClassNum  \
# 60      APPM           3570             001               B          18194
# 61      APPM           3570             002               B          22165
# 62      APPM           4120             001               B          22260
# 63      APPM           4360             001               B          18416
# 64      APPM           4360             002               B          18418
# 65      APPM           4370             001               B          30635
# 66      APPM           4390             001               B          30637
# 67      APPM           4560             001               B          24947
# 68      APPM           4720             002               B          23452
# 69      APPM           4720             004               B          24508
# 70      APPM           5120             001               B          22261
# ...
